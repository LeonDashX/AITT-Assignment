# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import datetime
import math

# %% [markdown]
# # Reading the CSV file

# %%
df = pd.read_csv("fraudTrain.csv")
df.T.head(23)
# Out:
#                                                 0        \
# Unnamed: 0                                            0
# trans_date_trans_time               2019-01-01 00:00:18
# cc_num                                 2703186189652095
# merchant                     fraud_Rippin, Kub and Mann
# category                                       misc_net
# amt                                                4.97
# first                                          Jennifer
# last                                              Banks
# gender                                                F
# street                                   561 Perry Cove
# city                                     Moravian Falls
# state                                                NC
# zip                                               28654
# lat                                             36.0788
# long                                           -81.1781
# city_pop                                           3495
# job                           Psychologist, counselling
# dob                                          1988-03-09
# trans_num              0b242abb623afc578575680df30655b9
# unix_time                                    1325376018
# merch_lat                                     36.011293
# merch_long                                   -82.048315
# is_fraud                                              0
#
#                                                  1        \
# Unnamed: 0                                             1
# trans_date_trans_time                2019-01-01 00:00:44
# cc_num                                      630423337322
# merchant                 fraud_Heller, Gutmann and Zieme
# category                                     grocery_pos
# amt                                               107.23
# first                                          Stephanie
# last                                                Gill
# gender                                                 F
# street                      43039 Riley Greens Suite 393
# city                                              Orient
# state                                                 WA
# zip                                                99160
# lat                                              48.8878
# long                                           -118.2105
# city_pop                                             149
# job                    Special educational needs teacher
# dob                                           1978-06-21
# trans_num               1f76529f8574734946361c461b024d99
# unix_time                                     1325376044
# merch_lat                                      49.159047
# merch_long                                   -118.186462
# is_fraud                                               0
#
#                                                 2        \
# Unnamed: 0                                            2
# trans_date_trans_time               2019-01-01 00:00:51
# cc_num                                   38859492057661
# merchant                           fraud_Lind-Buckridge
# category                                  entertainment
# amt                                              220.11
# first                                            Edward
# last                                            Sanchez
# gender                                                M
# street                         594 White Dale Suite 530
# city                                         Malad City
# state                                                ID
# zip                                               83252
# lat                                             42.1808
# long                                           -112.262
# city_pop                                           4154
# job                         Nature conservation officer
# dob                                          1962-01-19
# trans_num              a1a22d70485983eac12b5b88dad1cf95
# unix_time                                    1325376051
# merch_lat                                     43.150704
# merch_long                                  -112.154481
# is_fraud                                              0
#
#                                                   3        \
# Unnamed: 0                                              3
# trans_date_trans_time                 2019-01-01 00:01:16
# cc_num                                   3534093764340240
# merchant               fraud_Kutch, Hermiston and Farrell
# category                                    gas_transport
# amt                                                  45.0
# first                                              Jeremy
# last                                                White
# gender                                                  M
# street                        9443 Cynthia Court Apt. 038
# city                                              Boulder
# state                                                  MT
# zip                                                 59632
# lat                                               46.2306
# long                                            -112.1138
# city_pop                                             1939
# job                                       Patent attorney
# dob                                            1967-01-12
# trans_num                6b849c168bdad6f867558c3793159a81
# unix_time                                      1325376076
# merch_lat                                       47.034331
# merch_long                                    -112.561071
# is_fraud                                                0
#
#                                                 4        \
# Unnamed: 0                                            4
# trans_date_trans_time               2019-01-01 00:03:06
# cc_num                                  375534208663984
# merchant                            fraud_Keeling-Crist
# category                                       misc_pos
# amt                                               41.96
# first                                             Tyler
# last                                             Garcia
# gender                                                M
# street                                 408 Bradley Rest
# city                                           Doe Hill
# state                                                VA
# zip                                               24433
# lat                                             38.4207
# long                                           -79.4629
# city_pop                                             99
# job                      Dance movement psychotherapist
# dob                                          1986-03-28
# trans_num              a41d7549acf90789359a9aa5346dcb46
# unix_time                                    1325376186
# merch_lat                                     38.674999
# merch_long                                   -78.632459
# is_fraud                                              0
#
#                                                 5        \
# Unnamed: 0                                            5
# trans_date_trans_time               2019-01-01 00:04:08
# cc_num                                 4767265376804500
# merchant               fraud_Stroman, Hudson and Erdman
# category                                  gas_transport
# amt                                               94.63
# first                                          Jennifer
# last                                             Conner
# gender                                                F
# street                                4655 David Island
# city                                             Dublin
# state                                                PA
# zip                                               18917
# lat                                              40.375
# long                                           -75.2045
# city_pop                                           2158
# job                                   Transport planner
# dob                                          1961-06-19
# trans_num              189a841a0a8ba03058526bcfe566aab5
# unix_time                                    1325376248
# merch_lat                                     40.653382
# merch_long                                   -76.152667
# is_fraud                                              0
#
#                                                 6        \
# Unnamed: 0                                            6
# trans_date_trans_time               2019-01-01 00:04:42
# cc_num                                   30074693890476
# merchant                          fraud_Rowe-Vandervort
# category                                    grocery_net
# amt                                               44.54
# first                                            Kelsey
# last                                           Richards
# gender                                                F
# street                      889 Sarah Station Suite 624
# city                                            Holcomb
# state                                                KS
# zip                                               67851
# lat                                             37.9931
# long                                          -100.9893
# city_pop                                           2691
# job                                     Arboriculturist
# dob                                          1993-08-16
# trans_num              83ec1cc84142af6e2acf10c44949e720
# unix_time                                    1325376282
# merch_lat                                     37.162705
# merch_long                                   -100.15337
# is_fraud                                              0
#
#                                                 7        \
# Unnamed: 0                                            7
# trans_date_trans_time               2019-01-01 00:05:08
# cc_num                                 6011360759745864
# merchant                           fraud_Corwin-Collins
# category                                  gas_transport
# amt                                               71.65
# first                                            Steven
# last                                           Williams
# gender                                                M
# street                        231 Flores Pass Suite 720
# city                                           Edinburg
# state                                                VA
# zip                                               22824
# lat                                             38.8432
# long                                           -78.6003
# city_pop                                           6018
# job                                Designer, multimedia
# dob                                          1947-08-21
# trans_num              6d294ed2cc447d2c71c7171a3d54967c
# unix_time                                    1325376308
# merch_lat                                     38.948089
# merch_long                                   -78.540296
# is_fraud                                              0
#
#                                                 8        \
# Unnamed: 0                                            8
# trans_date_trans_time               2019-01-01 00:05:18
# cc_num                                 4922710831011201
# merchant                               fraud_Herzog Ltd
# category                                       misc_pos
# amt                                                4.27
# first                                           Heather
# last                                              Chase
# gender                                                F
# street                      6888 Hicks Stream Suite 954
# city                                              Manor
# state                                                PA
# zip                                               15665
# lat                                             40.3359
# long                                           -79.6607
# city_pop                                           1472
# job                           Public affairs consultant
# dob                                          1941-03-07
# trans_num              fc28024ce480f8ef21a32d64c93a29f5
# unix_time                                    1325376318
# merch_lat                                     40.351813
# merch_long                                   -79.958146
# is_fraud                                              0
#
#                                                  9        ...  \
# Unnamed: 0                                             9  ...
# trans_date_trans_time                2019-01-01 00:06:01  ...
# cc_num                                  2720830304681674  ...
# merchant               fraud_Schoen, Kuphal and Nitzsche  ...
# category                                     grocery_pos  ...
# amt                                               198.39  ...
# first                                            Melissa  ...
# last                                             Aguilar  ...
# gender                                                 F  ...
# street                    21326 Taylor Squares Suite 708  ...
# city                                         Clarksville  ...
# state                                                 TN  ...
# zip                                                37040  ...
# lat                                               36.522  ...
# long                                             -87.349  ...
# city_pop                                          151785  ...
# job                                          Pathologist  ...
# dob                                           1974-03-28  ...
# trans_num               3b9014ea8fb80bd65de0b1463b00b00e  ...
# unix_time                                     1325376361  ...
# merch_lat                                      37.179198  ...
# merch_long                                    -87.485381  ...
# is_fraud                                               0  ...
#
#                                                 1296665  \
# Unnamed: 0                                      1296665
# trans_date_trans_time               2020-06-21 12:08:42
# cc_num                                  213193596103206
# merchant                            fraud_Gulgowski LLC
# category                                           home
# amt                                               72.17
# first                                             James
# last                                               Hunt
# gender                                                M
# street                              7369 Gabriel Tunnel
# city                                    Pointe Aux Pins
# state                                                MI
# zip                                               49775
# lat                                             45.7549
# long                                            -84.447
# city_pop                                             95
# job                                 Electrical engineer
# dob                                          1994-02-09
# trans_num              108c103b26f686c24c021aaf4210977e
# unix_time                                    1371816522
# merch_lat                                     44.938461
# merch_long                                   -83.996234
# is_fraud                                              0
#
#                                                  1296666  \
# Unnamed: 0                                       1296666
# trans_date_trans_time                2020-06-21 12:09:22
# cc_num                               4587657402165341815
# merchant               fraud_Hyatt, Russel and Gleichner
# category                                  health_fitness
# amt                                                  7.3
# first                                              Amber
# last                                               Lewis
# gender                                                 F
# street                          6296 John Keys Suite 858
# city                                   Pembroke Township
# state                                                 IL
# zip                                                60958
# lat                                              41.0646
# long                                            -87.5917
# city_pop                                            2135
# job                               Psychotherapist, child
# dob                                           2004-05-08
# trans_num               37a18c6fb0c5c722b6339ffedc82f55a
# unix_time                                     1371816562
# merch_lat                                      40.556811
# merch_long                                    -88.092339
# is_fraud                                               0
#
#                                                   1296667  \
# Unnamed: 0                                        1296667
# trans_date_trans_time                 2020-06-21 12:10:56
# cc_num                                   4822367783500458
# merchant               fraud_Hahn, Douglas and Schowalter
# category                                           travel
# amt                                                 19.71
# first                                         Christopher
# last                                              Farrell
# gender                                                  M
# street                                97070 Anderson Land
# city                                          Haines City
# state                                                  FL
# zip                                                 33844
# lat                                               28.0758
# long                                             -81.5929
# city_pop                                            33804
# job                                 Exercise physiologist
# dob                                            1991-01-01
# trans_num                34e72e0a659a6c8f4a20ee65594f3a7d
# unix_time                                      1371816656
# merch_lat                                       27.465871
# merch_long                                     -81.511804
# is_fraud                                                0
#
#                                                 1296668  \
# Unnamed: 0                                      1296668
# trans_date_trans_time               2020-06-21 12:11:23
# cc_num                                  213141712584544
# merchant                    fraud_Metz, Russel and Metz
# category                                      kids_pets
# amt                                              100.85
# first                                          Margaret
# last                                             Curtis
# gender                                                F
# street                                 742 Oneill Shore
# city                                           Florence
# state                                                MS
# zip                                               39073
# lat                                              32.153
# long                                           -90.1217
# city_pop                                          19685
# job                                         Fine artist
# dob                                          1984-12-24
# trans_num              0d86d8c17638d7eff77db9c6a878b477
# unix_time                                    1371816683
# merch_lat                                     31.377697
# merch_long                                    -90.52845
# is_fraud                                              0
#
#                                                 1296669  \
# Unnamed: 0                                      1296669
# trans_date_trans_time               2020-06-21 12:11:36
# cc_num                              4400011257587661852
# merchant                           fraud_Stiedemann Inc
# category                                       misc_pos
# amt                                               37.38
# first                                           Marissa
# last                                             Powell
# gender                                                F
# street                                  474 Allen Haven
# city                                         North Loup
# state                                                NE
# zip                                               68859
# lat                                             41.4972
# long                                           -98.7858
# city_pop                                            509
# job                                   Nurse, children's
# dob                                          1980-09-15
# trans_num              9a7ea2625cf8303efe34e3c09546868f
# unix_time                                    1371816696
# merch_lat                                     41.728638
# merch_long                                    -99.03966
# is_fraud                                              0
#
#                                                 1296670  \
# Unnamed: 0                                      1296670
# trans_date_trans_time               2020-06-21 12:12:08
# cc_num                                   30263540414123
# merchant                              fraud_Reichel Inc
# category                                  entertainment
# amt                                               15.56
# first                                              Erik
# last                                          Patterson
# gender                                                M
# street                         162 Jessica Row Apt. 072
# city                                              Hatch
# state                                                UT
# zip                                               84735
# lat                                             37.7175
# long                                          -112.4777
# city_pop                                            258
# job                                        Geoscientist
# dob                                          1961-11-24
# trans_num              440b587732da4dc1a6395aba5fb41669
# unix_time                                    1371816728
# merch_lat                                     36.841266
# merch_long                                  -111.690765
# is_fraud                                              0
#
#                                                 1296671  \
# Unnamed: 0                                      1296671
# trans_date_trans_time               2020-06-21 12:12:19
# cc_num                                 6011149206456997
# merchant                       fraud_Abernathy and Sons
# category                                    food_dining
# amt                                                51.7
# first                                           Jeffrey
# last                                              White
# gender                                                M
# street                    8617 Holmes Terrace Suite 651
# city                                          Tuscarora
# state                                                MD
# zip                                               21790
# lat                                             39.2667
# long                                           -77.5101
# city_pop                                            100
# job                    Production assistant, television
# dob                                          1979-12-11
# trans_num              278000d2e0d2277d1de2f890067dcc0a
# unix_time                                    1371816739
# merch_lat                                     38.906881
# merch_long                                   -78.246528
# is_fraud                                              0
#
#                                                 1296672  \
# Unnamed: 0                                      1296672
# trans_date_trans_time               2020-06-21 12:12:32
# cc_num                                 3514865930894695
# merchant                           fraud_Stiedemann Ltd
# category                                    food_dining
# amt                                              105.93
# first                                       Christopher
# last                                          Castaneda
# gender                                                M
# street                       1632 Cohen Drive Suite 639
# city                           High Rolls Mountain Park
# state                                                NM
# zip                                               88325
# lat                                             32.9396
# long                                          -105.8189
# city_pop                                            899
# job                                     Naval architect
# dob                                          1967-08-30
# trans_num              483f52fe67fabef353d552c1e662974c
# unix_time                                    1371816752
# merch_lat                                     33.619513
# merch_long                                  -105.130529
# is_fraud                                              0
#
#                                                    1296673  \
# Unnamed: 0                                         1296673
# trans_date_trans_time                  2020-06-21 12:13:36
# cc_num                                    2720012583106919
# merchant               fraud_Reinger, Weissnat and Strosin
# category                                       food_dining
# amt                                                   74.9
# first                                               Joseph
# last                                                Murray
# gender                                                   M
# street                                42933 Ryan Underpass
# city                                             Manderson
# state                                                   SD
# zip                                                  57756
# lat                                                43.3526
# long                                             -102.5411
# city_pop                                              1126
# job                                  Volunteer coordinator
# dob                                             1980-08-18
# trans_num                 d667cdcbadaaed3da3f4020e83591c83
# unix_time                                       1371816816
# merch_lat                                         42.78894
# merch_long                                      -103.24116
# is_fraud                                                 0
#
#                                                    1296674
# Unnamed: 0                                         1296674
# trans_date_trans_time                  2020-06-21 12:13:37
# cc_num                                 4292902571056973207
# merchant               fraud_Langosh, Wintheiser and Hyatt
# category                                       food_dining
# amt                                                    4.3
# first                                              Jeffrey
# last                                                 Smith
# gender                                                   M
# street                                135 Joseph Mountains
# city                                                  Sula
# state                                                   MT
# zip                                                  59871
# lat                                                45.8433
# long                                             -113.8748
# city_pop                                               218
# job                               Therapist, horticultural
# dob                                             1995-08-16
# trans_num                 8f7c8e4ab7f25875d753b422917c98c9
# unix_time                                       1371816817
# merch_lat                                        46.565983
# merch_long                                      -114.18611
# is_fraud                                                 0
#
# [23 rows x 1296675 columns]

# %% [markdown]
# # Finding out each columns name

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %% [markdown]
# # Shape of dataset

# %%
df.shape
# Out:
# (1296675, 23)

# %% [markdown]
# # Check for missing values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# # Check for duplicate rows in dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Ensuring data in columns have appropriate data type for analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
#  14  long                   1296675 non-null  float64
#  15  city_pop               1296675 non-null  int64
#  16  job                    1296675 non-null  object
#  17  dob                    1296675 non-null  object
#  18  trans_num              1296675 non-null  object
#  19  unix_time              1296675 non-null  int64
#  20  merch_lat              1296675 non-null  float64
#  21  merch_long             1296675 non-null  float64
#  22  is_fraud               1296675 non-null  int64
# dtypes: float64(5), int64(6), object(12)
# memory usage: 227.5+ MB

# %%
df.describe().T
# Out:
#                 count          mean           std           min           25%  \
# Unnamed: 0  1296675.0  6.483370e+05  3.743180e+05  0.000000e+00  3.241685e+05
# cc_num      1296675.0  4.171920e+17  1.308806e+18  6.041621e+10  1.800429e+14
# amt         1296675.0  7.035104e+01  1.603160e+02  1.000000e+00  9.650000e+00
# zip         1296675.0  4.880067e+04  2.689322e+04  1.257000e+03  2.623700e+04
# lat         1296675.0  3.853762e+01  5.075808e+00  2.002710e+01  3.462050e+01
# long        1296675.0 -9.022634e+01  1.375908e+01 -1.656723e+02 -9.679800e+01
# city_pop    1296675.0  8.882444e+04  3.019564e+05  2.300000e+01  7.430000e+02
# unix_time   1296675.0  1.349244e+09  1.284128e+07  1.325376e+09  1.338751e+09
# merch_lat   1296675.0  3.853734e+01  5.109788e+00  1.902779e+01  3.473357e+01
# merch_long  1296675.0 -9.022646e+01  1.377109e+01 -1.666712e+02 -9.689728e+01
# is_fraud    1296675.0  5.788652e-03  7.586269e-02  0.000000e+00  0.000000e+00
#
#                      50%           75%           max
# Unnamed: 0  6.483370e+05  9.725055e+05  1.296674e+06
# cc_num      3.521417e+15  4.642255e+15  4.992346e+18
# amt         4.752000e+01  8.314000e+01  2.894890e+04
# zip         4.817400e+04  7.204200e+04  9.978300e+04
# lat         3.935430e+01  4.194040e+01  6.669330e+01
# long       -8.747690e+01 -8.015800e+01 -6.795030e+01
# city_pop    2.456000e+03  2.032800e+04  2.906700e+06
# unix_time   1.349250e+09  1.359385e+09  1.371817e+09
# merch_lat   3.936568e+01  4.195716e+01  6.751027e+01
# merch_long -8.743839e+01 -8.023680e+01 -6.695090e+01
# is_fraud    0.000000e+00  0.000000e+00  1.000000e+00

# %% [markdown]
# # Check for na missing values

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# # To check if each column has the same data type

# %%
for col in df.columns:
    print(f"{col}: {df[col].apply(type).nunique()} unique types")
# Out:
# Unnamed: 0: 1 unique types
# trans_date_trans_time: 1 unique types
# cc_num: 1 unique types
# merchant: 1 unique types
# category: 1 unique types
# amt: 1 unique types
# first: 1 unique types
# last: 1 unique types
# gender: 1 unique types
# street: 1 unique types
# city: 1 unique types
# state: 1 unique types
# zip: 1 unique types
# lat: 1 unique types
# long: 1 unique types
# city_pop: 1 unique types
# job: 1 unique types
# dob: 1 unique types
# trans_num: 1 unique types
# unix_time: 1 unique types
# merch_lat: 1 unique types
# merch_long: 1 unique types
# is_fraud: 1 unique types

# %% [markdown]
# # To check for columns with constant values

# %%
for col in df.select_dtypes(exclude=['object']):
    if df[col].nunique() == 1:
        print(f"Column '{col}' has a single unique value.")
    else:
        print(f"Column '{col}' has {df[col].nunique()} unique values.")
# Out:
# Column 'Unnamed: 0' has 1296675 unique values.
# Column 'cc_num' has 983 unique values.
# Column 'amt' has 52928 unique values.
# Column 'zip' has 970 unique values.
# Column 'lat' has 968 unique values.
# Column 'long' has 969 unique values.
# Column 'city_pop' has 879 unique values.
# Column 'unix_time' has 1274823 unique values.
# Column 'merch_lat' has 1247805 unique values.
# Column 'merch_long' has 1275745 unique values.
# Column 'is_fraud' has 2 unique values.

# %%
df.nunique()
# Out:
# Unnamed: 0               1296675
# trans_date_trans_time    1274791
# cc_num                       983
# merchant                     693
# category                      14
# amt                        52928
# first                        352
# last                         481
# gender                         2
# street                       983
# city                         894
# state                         51
# zip                          970
# lat                          968
# long                         969
# city_pop                     879
# job                          494
# dob                          968
# trans_num                1296675
# unix_time                1274823
# merch_lat                1247805
# merch_long               1275745
# is_fraud                       2
# dtype: int64

# %% [markdown]
# # Correlation of values

# %%
# Choose only numerical values columns
df_numerical = df.select_dtypes(include=[np.number])


plt.figure(figsize=(12,10))
sns.heatmap(df_numerical.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation matrix for numerical columns")
plt.show()

# %%
# Check class distribution
class_distribution = df['is_fraud'].value_counts(normalize=True)

print("Class Distribution (%):")
print(class_distribution * 100)
# Out:
# Class Distribution (%):
# is_fraud
# 0    99.421135
# 1     0.578865
# Name: proportion, dtype: float64

# %% [markdown]
# # Key summary:
# > No Missing values data set;
# >
# > No duplicated values/rows;
# >
# > trans_date_trans_time and dob are in object format, we will have to change it to DateTime Format for EDA and preprocessing;
# >
# > All the input data columns are of continuous numeric data. There are no columns with constant values;
# >
# > is_fraud is target variable

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # First, create a copy of the dataset for all eda showcase.

# %%
df_for_eda = df.copy()
df_for_eda.head(1)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
#
#                      merchant  category   amt     first   last gender  \
# 0  fraud_Rippin, Kub and Mann  misc_net  4.97  Jennifer  Banks      F
#
#            street  ...      lat     long  city_pop                        job  \
# 0  561 Perry Cove  ...  36.0788 -81.1781      3495  Psychologist, counselling
#
#           dob                         trans_num   unix_time  merch_lat  \
# 0  1988-03-09  0b242abb623afc578575680df30655b9  1325376018  36.011293
#
#   merch_long  is_fraud
# 0 -82.048315         0
#
# [1 rows x 23 columns]

# %% [markdown]
# # Now we have to convert trans_date_trans_time to datetime format

# %%
df_for_eda['trans_date_trans_time'] = pd.to_datetime(df_for_eda['trans_date_trans_time'])

df_for_eda['transaction_HOUR'] = df_for_eda['trans_date_trans_time'].dt.hour

df_for_eda['day_of_WEEK'] = df_for_eda['trans_date_trans_time'].dt.day_name()

df_for_eda['transaction_MONTH'] = df_for_eda['trans_date_trans_time'].dt.month

df_for_eda['is_WEEKEND'] = df_for_eda['trans_date_trans_time'].dt.weekday.isin([5, 6]).astype(int)

def categorize_daytiming(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    elif 21 <= hour or hour < 5:
        return 'Night'

df_for_eda['day_TIMING'] = df_for_eda['transaction_HOUR'].apply(categorize_daytiming)

df_for_eda[['transaction_HOUR', 'day_of_WEEK', 'transaction_MONTH', 'day_TIMING', 'is_WEEKEND']].head()
# Out:
#    transaction_HOUR day_of_WEEK  transaction_MONTH day_TIMING  is_WEEKEND
# 0                 0     Tuesday                  1      Night           0
# 1                 0     Tuesday                  1      Night           0
# 2                 0     Tuesday                  1      Night           0
# 3                 0     Tuesday                  1      Night           0
# 4                 0     Tuesday                  1      Night           0

# %% [markdown]
# # We would also do the same for DOB, to change DOB to datetime format

# %%
df_for_eda['dob'] = pd.to_datetime(df_for_eda['dob'], errors='coerce')

# Calculate age as of January 30, 2025
reference_date = datetime(2025, 1, 30) 
df_for_eda['age'] = (reference_date - df_for_eda['dob']).dt.days // 365 

df_for_eda['age'].describe()
# Out:
# count    1.296675e+06
# mean     5.085907e+01
# std      1.740296e+01
# min      2.000000e+01
# 25%      3.700000e+01
# 50%      4.900000e+01
# 75%      6.200000e+01
# max      1.000000e+02
# Name: age, dtype: float64

# %% [markdown]
# # Creating a more detailed age group column

# %%
def categorize_age_group(age):
    if age <= 12:
        return 'Child'
    elif 13 <= age <= 17:
        return 'Teenager'
    elif 18 <= age <= 25:
        return 'Young Adult'
    elif 26 <= age <= 40:
        return 'Adult'
    elif 41 <= age <= 60:
        return 'Middle-Aged'
    elif 61 <= age <= 80:
        return 'Senior'
    else:
        return 'Elderly'

df_for_eda['age_group'] = df_for_eda['age'].apply(categorize_age_group)


df_for_eda[['age', 'age_group']].head()
# Out:
#    age    age_group
# 0   36        Adult
# 1   46  Middle-Aged
# 2   63       Senior
# 3   58  Middle-Aged
# 4   38        Adult

# %% [markdown]
# #  Now we will calculate distance between cardholder and merchant

# %%
def calculate_distance(X, lat_col, long_col, merch_lat_col, merch_long_col, new_column):
    
    X = X.copy()

    lat1 = np.radians(X[lat_col])
    lon1 = np.radians(X[long_col])
    lat2 = np.radians(X[merch_lat_col])
    lon2 = np.radians(X[merch_long_col])
    
    # Haversine formula to calculate distance
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    R = 6371  # Radius of the Earth in kilometers
    X[new_column] = R * c  # Distance in kilometers

    return X

# %%
df_for_eda = calculate_distance(df_for_eda, 'lat', 'long', 'merch_lat', 'merch_long', 'distance')

# Display the new 'distance' column
df_for_eda[['lat', 'long', 'merch_lat', 'merch_long', 'distance']].head()
# Out:
#        lat      long  merch_lat  merch_long    distance
# 0  36.0788  -81.1781  36.011293  -82.048315   78.597568
# 1  48.8878 -118.2105  49.159047 -118.186462   30.212176
# 2  42.1808 -112.2620  43.150704 -112.154481  108.206083
# 3  46.2306 -112.1138  47.034331 -112.561071   95.673231
# 4  38.4207  -79.4629  38.674999  -78.632459   77.556744

# %%
df_for_eda['distance'].describe()
# Out:
# count    1.296675e+06
# mean     7.611465e+01
# std      2.911693e+01
# min      2.225452e-02
# 25%      5.533491e+01
# 50%      7.823175e+01
# 75%      9.850327e+01
# max      1.521172e+02
# Name: distance, dtype: float64

# %% [markdown]
# # Now we will create bins for city population

# %%
city_pop_bins = [0, 10000, 50000, 100000, 500000, 1000000, np.inf]
city_pop_labels = ['<10K', '10K-50K', '50K-100K', '100K-500K', '500K-1M', '>1M']

# Bin the 'city_pop' column
df_for_eda['city_pop_bin'] = pd.cut(df_for_eda['city_pop'], bins=city_pop_bins, labels=city_pop_labels)

# %% [markdown]
# # Now we will drop unwanteded columns for EDA

# %%
columns_to_remove = ['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant',
        'first', 'last',  'street', 'city', 'state', 'zip',
       'lat', 'long',  'job', 'dob', 'trans_num', 'unix_time',
       'merch_lat', 'merch_long'
]


df_for_eda.drop(columns=columns_to_remove, inplace=True)

# %%
df_for_eda.columns
# Out:
# Index(['category', 'amt', 'gender', 'city_pop', 'is_fraud', 'transaction_HOUR',
#        'day_of_WEEK', 'transaction_MONTH', 'is_WEEKEND', 'day_TIMING', 'age',
#        'age_group', 'distance', 'city_pop_bin'],
#       dtype='object')

# %% [markdown]
# # Now we will start with our EDA. Firstly, the distribution of target variable of is_fraud is:

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='is_fraud', data=df_for_eda , palette='viridis')
plt.title('Distribution of Fraudulent Transactions')
plt.xlabel('Fraudulent Transaction')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Joshua Leong\AppData\Local\Temp\ipykernel_6028\3726995150.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='is_fraud', data=df_for_eda , palette='viridis')

# %% [markdown]
# # As we can see from the graph above, there are alot more non fraudulent transactions then fraudulent transactions, which cause the dataset to be imbalanced. So what is the distribution of transaction amount

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_for_eda['amt'], kde=True, bins=50)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # The transaction amounts shows that there are a large number of small transactions and few large transactions. From the first and second graph, this could possibly indicate that large transactions are potentially fraudulent activity
# > So what is the average amount transacted that are fruad and non-fraud?

# %%
avg_amt_fraud = df_for_eda.groupby('is_fraud')['amt'].mean()


avg_amt_fraud.plot(kind='bar', figsize=(6, 4))
plt.title('Average Transaction Amount by Fraud Status')
plt.ylabel('Average Amount')
plt.xticks(ticks=[0, 1], labels=['Non-Fraud', 'Fraud'], rotation=0)
plt.show()

# %% [markdown]
# # The fraudulent transactions show a higher average amount.
# > How does the day of the week affect the occurrence of fraud?

# %%
fraud_by_day = df_for_eda.groupby('day_of_WEEK')['is_fraud'].sum()

plt.figure(figsize=(8, 6))
fraud_by_day.sort_values().plot(kind='bar', color='green')
plt.title('Fraudulent Transactions by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Fraudulent Transactions')
plt.show()

# %% [markdown]
# # This shows that fraudulant transactions occur more during the weekend and monday
# **Is there a correlation between age and fraud transactions?**

# %%
fraud_by_age = df_for_eda.groupby('age')['is_fraud'].sum()

plt.figure(figsize=(8, 6))
fraud_by_age.plot(kind='line', color='orange')
plt.title('Fraudulent Transactions by Age')
plt.xlabel('Age')
plt.ylabel('Number of Fraudulent Transactions')
plt.show()

# %% [markdown]
# # Highest number of fraud transaction occur usually within age 30 to age 40
# **How does the timing of the day relate with fraud?**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='day_TIMING', hue='is_fraud', data=df_for_eda, palette='coolwarm')
plt.title('Fraudulent Transactions by Part of Day')
plt.xlabel('Part of Day')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # This shows that fraudulent transactions happens very often in night time compared to the rest of the day
# **So during which hour does fraudulent transaction really happen often?**

# %%
fraud_by_hour = df_for_eda.groupby('transaction_HOUR')['is_fraud'].sum()

plt.figure(figsize=(8, 6))
fraud_by_hour.plot(kind='line', color='green')
plt.title('Fraudulent Transactions by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Fraudulent Transactions')
plt.show()

# %% [markdown]
# # This shows that the fraudulent transactions are happening more on 22nd hour and also happen quite a few from midnight to 4th hour
# **How does age group affect fraud occurences? Does it happen within young adults, or more towards elderly?**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='age_group', hue='is_fraud', data=df_for_eda, palette='Set2')
plt.title('Fraudulent Transactions by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # This shows that fraudulent transactions happen more within middle-aged group of people
# **So are there any correlation between distance of merchant and cardholder and fraud activities? Does far distance usually indicate fraud?**

# %%
distance_bins = np.linspace(df_for_eda['distance'].min(), df_for_eda['distance'].max(), num=20)
# Bin the 'distance' column
df_for_eda['distance_bin'] = pd.cut(df_for_eda['distance'], bins=distance_bins)

# Group by distance bins and calculate the sum of fraudulent transactions
fraud_by_distance_bin = df_for_eda.groupby('distance_bin')['is_fraud'].sum()

# Plot the result
plt.figure(figsize=(10, 6))
fraud_by_distance_bin.plot(kind='bar', color='green')
plt.title('Fraudulent Transactions by Distance (Binned)')
plt.xlabel('Distance Bins')
plt.ylabel('Number of Fraudulent Transactions')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Joshua Leong\AppData\Local\Temp\ipykernel_6028\1772917706.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_by_distance_bin = df_for_eda.groupby('distance_bin')['is_fraud'].sum()

# %% [markdown]
# # The fraudulent transactions are higher around 64-80km distance.
# **What is the relationship between city_pop and fraud?**

# %%
# Group by the 'city_pop_bin' and calculate the sum of fraudulent transactions
fraud_by_city_pop_bin = df_for_eda.groupby('city_pop_bin')['is_fraud'].sum()

# Plot the result as a bar plot
plt.figure(figsize=(10, 6))
fraud_by_city_pop_bin.plot(kind='bar', color='orange')
plt.title('Fraudulent Transactions by City Population (Binned)')
plt.xlabel('City Population Bins')
plt.ylabel('Number of Fraudulent Transactions')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Joshua Leong\AppData\Local\Temp\ipykernel_6028\3318142288.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_by_city_pop_bin = df_for_eda.groupby('city_pop_bin')['is_fraud'].sum()

# %% [markdown]
# # City with lower population have higher fraud transaction, and cities with 100k-500k population have more fraud transaction then 50k-100k and cities with more than 500k population

# %% [markdown]
# There are 7 numerical features 'amt', 'city_pop', 'transaction_hour', 'transaction_month', 'is_weekend', 'age', 'distance'
#
# There are 3 discrete numerical features : 'transaction_hour', 'transaction_month', 'is_weekend'
#
# There are 4 continuos numerical features : 'amt', 'city_pop', 'age', 'distance'
#
# There are 4 categorical features : 'gender', 'day_of_week', 'part_of_day', 'age_group'

# %%
numerical_features = ['amt', 'city_pop', 'transaction_hour', 'transaction_month', 'is_weekend', 'age', 'distance']
discrete_numerical_features = [ 'transaction_hour', 'transaction_month', 'is_weekend']
continuous_numerical_features = ['amt', 'city_pop', 'age', 'distance']
categorical_features = ['gender', 'day_of_week', 'part_of_day', 'age_group']

# %% [markdown]
# # First we will see the boxplot of continuous_numerical_features

# %%
def plot_boxplot(feature):
    plt.figure(figsize=(6, 4))
    sns.boxplot(
        y=df_for_eda[feature], 
        notch=True,  # Add notch to the boxplot
        showcaps=False,  # Hide the caps
        flierprops={"marker": "x", "color": "r", "markersize": 8},  # Customize outliers
        boxprops={"facecolor": (.3, .5, .7, .5)},  # Set the box color with transparency
        medianprops={"color": "r", "linewidth": 2},  # Customize the median line
        whiskerprops={"color": "black", "linewidth": 1.5},  # Customize whiskers
        width=0.4  # Shrink the box width
    )
    plt.title(f'Boxplot for {feature}')
    plt.xlabel('')
    plt.ylabel(feature)
    plt.show()

# %%
plot_boxplot("amt")

# %%
plot_boxplot("city_pop")

# %%
plot_boxplot("age")

# %%
plot_boxplot("distance")

# %% [markdown]
# # Now we will see histograms of continuous numerical features

# %%
def plot_histogram(feature, bins=10):
    plt.figure(figsize=(6, 4))
    sns.histplot(df_for_eda[feature], bins=bins, kde=True, color="blue", alpha=0.6)
    plt.title(f'Histogram for {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()

# %%
plot_histogram("amt")

# %%
plot_histogram("city_pop")

# %%
plot_histogram("age")

# %%
plot_histogram("distance")

# %% [markdown]
# # From the information above, the amt column and city_pop is highly skewed

# %%
a = df_for_eda

# %%
a.columns
# Out:
# Index(['category', 'amt', 'gender', 'city_pop', 'is_fraud', 'transaction_HOUR',
#        'day_of_WEEK', 'transaction_MONTH', 'is_WEEKEND', 'day_TIMING', 'age',
#        'age_group', 'distance', 'city_pop_bin', 'distance_bin'],
#       dtype='object')

# %%
a.head()
# Out:
#         category     amt gender  city_pop  is_fraud  transaction_HOUR  \
# 0       misc_net    4.97      F      3495         0                 0
# 1    grocery_pos  107.23      F       149         0                 0
# 2  entertainment  220.11      M      4154         0                 0
# 3  gas_transport   45.00      M      1939         0                 0
# 4       misc_pos   41.96      M        99         0                 0
#
#   day_of_WEEK  transaction_MONTH  is_WEEKEND day_TIMING  age    age_group  \
# 0     Tuesday                  1           0      Night   36        Adult
# 1     Tuesday                  1           0      Night   46  Middle-Aged
# 2     Tuesday                  1           0      Night   63       Senior
# 3     Tuesday                  1           0      Night   58  Middle-Aged
# 4     Tuesday                  1           0      Night   38        Adult
#
#      distance city_pop_bin        distance_bin
# 0   78.597568         <10K    (72.067, 80.072]
# 1   30.212176         <10K    (24.037, 32.042]
# 2  108.206083         <10K  (104.087, 112.092]
# 3   95.673231         <10K    (88.077, 96.082]
# 4   77.556744         <10K    (72.067, 80.072]

# %%
a.nunique()
# Out:
# category                  14
# amt                    52928
# gender                     2
# city_pop                 879
# is_fraud                   2
# transaction_HOUR          24
# day_of_WEEK                7
# transaction_MONTH         12
# is_WEEKEND                 2
# day_TIMING                 4
# age                       80
# age_group                  5
# distance             1296675
# city_pop_bin               6
# distance_bin              19
# dtype: int64

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# > Logistic Regression is used as we will be classifying the "is_fraud" with either be True or False

# %% [markdown]
# # Preparing the Dataset for Logistic Regression using One-Hot Encoding

# %%
c = a['is_fraud'] #c variable contains data to be predicted

#encoding non-numeric data, b varaible contains all data used for machine learning
b = pd.get_dummies(a, columns=['day_of_WEEK'], drop_first=True)
b = pd.get_dummies(b, columns=['gender'], drop_first=True)
b = pd.get_dummies(b, columns=['day_TIMING'], drop_first=True)
b = pd.get_dummies(b, columns=['age_group'], drop_first=True)
b = pd.get_dummies(b, columns=['category'], drop_first=True)
b = pd.get_dummies(b, columns=['city_pop_bin'], drop_first=True)
b = pd.get_dummies(b, columns=['distance_bin'], drop_first=True)
b = b.drop('city_pop',axis=1)
b = b.drop('distance',axis=1)
b = b.drop('is_fraud',axis=1) #drops the dependent variable "is_fraud" from the other variables
b.iloc[0]
# Out:
# amt                                 4.97
# transaction_HOUR                       0
# transaction_MONTH                      1
# is_WEEKEND                             0
# age                                   36
# day_of_WEEK_Monday                 False
# day_of_WEEK_Saturday               False
# day_of_WEEK_Sunday                 False
# day_of_WEEK_Thursday               False
# day_of_WEEK_Tuesday                 True
# day_of_WEEK_Wednesday              False
# gender_M                           False
# day_TIMING_Evening                 False
# day_TIMING_Morning                 False
# day_TIMING_Night                    True
# age_group_Elderly                  False
# age_group_Middle-Aged              False
# age_group_Senior                   False
# age_group_Young Adult              False
# category_food_dining               False
# category_gas_transport             False
# category_grocery_net               False
# category_grocery_pos               False
# category_health_fitness            False
# category_home                      False
# category_kids_pets                 False
# category_misc_net                   True
# category_misc_pos                  False
# category_personal_care             False
# category_shopping_net              False
# category_shopping_pos              False
# category_travel                    False
# city_pop_bin_10K-50K               False
# city_pop_bin_50K-100K              False
# city_pop_bin_100K-500K             False
# city_pop_bin_500K-1M               False
# city_pop_bin_>1M                   False
# distance_bin_(8.027, 16.032]       False
# distance_bin_(16.032, 24.037]      False
# distance_bin_(24.037, 32.042]      False
# distance_bin_(32.042, 40.047]      False
# distance_bin_(40.047, 48.052]      False
# distance_bin_(48.052, 56.057]      False
# distance_bin_(56.057, 64.062]      False
# distance_bin_(64.062, 72.067]      False
# distance_bin_(72.067, 80.072]       True
# distance_bin_(80.072, 88.077]      False
# distance_bin_(88.077, 96.082]      False
# distance_bin_(96.082, 104.087]     False
# distance_bin_(104.087, 112.092]    False
# distance_bin_(112.092, 120.097]    False
# distance_bin_(120.097, 128.102]    False
# distance_bin_(128.102, 136.107]    False
# distance_bin_(136.107, 144.112]    False
# distance_bin_(144.112, 152.117]    False
# Name: 0, dtype: object

# %% [markdown]
# # Performing train test spliting  on the data

# %%
from sklearn.model_selection import train_test_split
b_train, b_test, c_train, c_test = train_test_split(b, c, test_size=0.1, random_state=101)

# %% [markdown]
# # Creating a StandardScaler object and normalizing the training and testing data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
b_train_scaled = scaler.fit_transform(b_train)
b_test_scaled = scaler.transform(b_test)

# %% [markdown]
# # Creating a Logistic Regression model and training it

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(b_train_scaled, c_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model predictions

# %%
c_pred = model.predict(b_test_scaled)

#count the number of "fradulent" transactions in the test data
z = 0
for i in c_pred:
    if i == 1:
        z+=1
        
print("Total number of cases: {}\nNumber of predicted Fradulent cases: {}".format(len(c_pred),z))
# Out:
# Total number of cases: 129668
# Number of predicted Fradulent cases: 162

# %% [markdown]
# # Model Evaluation using Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
cm = pd.DataFrame(confusion_matrix(c_test, c_pred), index=['actual_no', 'actual_fraud'], columns=['predicted_no', 'predicted_fraud'])
cm
# Out:
#               predicted_no  predicted_fraud
# actual_no           128834               62
# actual_fraud           672              100

# %% [markdown]
# # Graphical View of Confusion Matrix

# %%
plt.figure()
disp = ConfusionMatrixDisplay(confusion_matrix(c_test, c_pred), display_labels=['No Fraud', 'Fraud'])
disp.plot(cmap='plasma', values_format='d', colorbar=True)
plt.xlabel('Predictions')
plt.ylabel('Actual')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Creating Functions to calculate the Precision, Recall, F1 Score and Accuracy

# %%
def prec(TP, FP, TN, FN): #Function for Precision
    p = TP/(TP+FP)
    return p;
def rec(TP, FP, TN, FN): #Function for Recall
    r = TP/(TP+FN)
    return r;
def fs(TP, FP, TN, FN): #Function for F1 Score
    p = prec(TP, FP, TN, FN)
    r = rec(TP, FP, TN, FN)
    f1 = 2*((p*r)/(p+r))
    return f1;
def acc(TP, FP, TN, FN): #Function for Accuracy
    a = (TP+TN)/(TP+TN+FN+FP)
    return a;

# %%
cm
# Out:
#               predicted_no  predicted_fraud
# actual_no           128834               62
# actual_fraud           672              100

# %% [markdown]
# # Calculation for predicted "fraud"

# %%
p = prec(100, 62, 128832, 677) #Calculating precision
r = rec(100, 62, 128832, 677) #Calculating recall
f = fs(100, 62, 128832, 677) #Calculating f1-score
a = acc(100, 62, 128832, 677) #Calculating accuracy
print("Precision: {:.2f}\nRecall: {:.2f}\nF1-Score: {:.2f}\nAccuracy: {:.2f}".format(p,r,f,a))
# Out:
# Precision: 0.62
# Recall: 0.13
# F1-Score: 0.21
# Accuracy: 0.99

# %% [markdown]
# # Calculation for predicted "not fraud"

# %%
#values of "True positive" and "False positive" swapped to calculate for "not fraud"
p = prec(128832, 677, 100, 62) #Calculating precision
r = rec(128832, 677, 100, 62) #Calculating recall
f = fs(128832, 677, 100, 62) #Calculating f1-score
a = acc(128832, 677, 100, 62) #Calculating accuracy
print("Precision: {:.2f}\nRecall: {:.2f}\nF1-Score: {:.2f}\nAccuracy: {:.2f}".format(p,r,f,a))
# Out:
# Precision: 0.99
# Recall: 1.00
# F1-Score: 1.00
# Accuracy: 0.99

# %% [markdown]
# # Classification report on the results

# %% [markdown]
# > We can deduce the calculated values above and that of the classification report below do match

# %%
print(classification_report(c_test, c_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    128896
#            1       0.62      0.13      0.21       772
#
#     accuracy                           0.99    129668
#    macro avg       0.81      0.56      0.61    129668
# weighted avg       0.99      0.99      0.99    129668

# %% [markdown]
# # From the above classification report, we can see that the precision and recall of fraud indentification is quite low. The most significant is recall, showing that only 0.12 (12%) of actual fraud cases were correctly identified, which is incredibly low. The f1-score is also really low (20%), showing a poor balance between precision and recall. Therefore, we will attempt to balance out the f1-score for fraud identification.

# %% [markdown]
# # Optimizing the Logistic Regression parameters

# %%
lr = LogisticRegression(class_weight={0:1,1:15}, C=1.0, max_iter=5000)
lr.fit(b_train,c_train)
# Out:
# LogisticRegression(class_weight={0: 1, 1: 15}, max_iter=5000)

# %% [markdown]
# > The above class weight specifies that detecting "fraud" should be prioritised more than "not fraud".

# %%
pred = lr.predict(b_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
plt.figure()
disp = ConfusionMatrixDisplay(confusion_matrix(c_test, pred), display_labels=['No Fraud', 'Fraud'])
disp.plot(cmap='plasma', values_format='d', colorbar=True)
plt.xlabel('Predictions')
plt.ylabel('Actual')
plt.gca().invert_yaxis()
plt.show()

# %%
print(classification_report(c_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    128896
#            1       0.42      0.61      0.50       772
#
#     accuracy                           0.99    129668
#    macro avg       0.71      0.80      0.75    129668
# weighted avg       0.99      0.99      0.99    129668

# %% [markdown]
# # The classification report above contains the highest f1-score out of multiple tests.
